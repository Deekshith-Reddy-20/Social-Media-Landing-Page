# %% [markdown]
# <a href="https://colab.research.google.com/github/Deekshith-Reddy-20/Social-Media-Landing-Page/blob/main/Social_Media_App_Landing_Page.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.core.display import display, HTML

html_code = """
<!DOCTYPE html>
<html>
<head>
  <style>
    * {
      margin: 0;
      padding: 0;
      box-sizing: border-box;
    }
    body {
      font-family: 'Roboto', sans-serif;
      background: #f0f2f5;
      color: #333;
    }
    nav {
      background: #4267b2;
      color: yellow;
      display: flex;
      justify-content: space-between;
      padding: 1rem 2rem;
    }
    nav h1 {
      font-weight: 700;
    }
    nav ul {
      display: flex;
      gap: 1.5rem;
      list-style: none;
    }
    nav a {
      color: white;
      text-decoration: none;
      font-weight: 500;
    }
    .hero {
      text-align: center;
      padding: 4rem 2rem;
      background: linear-gradient(90deg, #4c6ef5, #5f27cd);
      color: white;
    }
    .btn-group {
      margin-top: 1.5rem;
    }
    .btn {
      background: white;
      color: #5f27cd;
      padding: 0.7rem 1.5rem;
      margin: 0 0.5rem;
      border-radius: 5px;
      text-decoration: none;
      font-weight: bold;
    }
    .btn.outline {
      background: transparent;
      border: 2px solid white;
      color: white;
    }
    .features {
      padding: 3rem 2rem;
      text-align: center;
    }
    .feature-cards {
      display: flex;
      justify-content: center;
      gap: 1.5rem;
      flex-wrap: wrap;
      margin-top: 2rem;
    }
    .card {
      background: white;
      padding: 1.5rem;
      border-radius: 10px;
      box-shadow: 0 0 12px rgba(0,0,0,0.1);
      width: 220px;
    }
    footer {
      background: #222;
      color: white;
      text-align: center;
      padding: 1rem;
      margin-top: 2rem;
    }
  </style>
</head>
<body>
  <nav>
    <h1>KiNdly</h1>
    <ul>
      <li><a href="#">Home</a></li>
      <li><a href="#">Features</a></li>
      <li><a href="#">About</a></li>
      <li><a href="#">Download</a></li>
    </ul>
  </nav>

  <header class="hero">
    <h2>Connect💬  Share📲 and  Close 🧑‍🤝‍🧑</h2>
    <p>The Generation Alpha social media app that brings people closer.</p>
    <div class="btn-group">
      <a href="#" class="btn">Download on Play Store</a>
      <a href="#" class="btn outline">App Store</a>
    </div>
  </header>

  <section class="features">
    <h2>Features</h2>
    <div class="feature-cards">
      <div class="card">👥 Connect with friends</div>
      <div class="card">📸 Share your moments</div>
      <div class="card">📢 Follow trending topics</div>
    </div>
  </section>

  <footer>
    <p>© 2025 Connectly. All rights reserved.</p>
  </footer>
</body>
</html>
"""

display(HTML(html_code))
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#   <style>
#     * {
#       margin: 0;
#       padding: 0;
#       box-sizing: border-box;
#     }
#     body {
#       font-family: 'Roboto', sans-serif;
#       background: #f0f2f5;
#       color: #333;
#     }
#     nav {
#       background: #4267b2;
#       color: yellow;
#       display: flex;
#       justify-content: space-between;
#       padding: 1rem 2rem;
#     }
#     nav h1 {
#       font-weight: 700;
#     }
#     nav ul {
#       display: flex;
#       gap: 1.5rem;
#       list-style: none;
#     }
#     nav a {
#       color: white;
#       text-decoration: none;
#       font-weight: 500;
#     }
#     .hero {
#       text-align: center;
#       padding: 4rem 2rem;
#       background: linear-gradient(90deg, #4c6ef5, #5f27cd);
#       color: white;
#     }
#     .btn-group {
#       margin-top: 1.5rem;
#     }
#     .btn {
#       background: white;
#       color: #5f27cd;
#       padding: 0.7rem 1.5rem;
#       margin: 0 0.5rem;
# ...
